# %% [markdown]
# -- <font color='gray'>**Adam Hughes**</font>
#
# -- <font color='gray'>**2/27/14**</font>
#
# -- <font color='gray'>**The George Washington University**</font>

# %% [markdown]
# # MultiCanvas Tutorial

# %% [markdown]
# ### Objective

# %% [markdown]
# This notebook will demonstrate some of the basic features of **MultiCanvas**, the canonical container class for **Canvas**.  A good real-world utilization is in the notebook, [labeling nanogold](http://nbviewer.ipython.org/github/hugadams/pyparty/blob/master/examples/Notebooks/groups_of_labels.ipynb?create=1).

# %% [markdown]
# ### Environment Setup

# %% [markdown]
# Configure notebook style (see NBCONFIG.ipynb), add imports and paths.  The **%run** magic used below <font color='red'>**requires IPython 2.0 or higher.**</font>

# %%
# %run NBCONFIG.ipynb
# Out:
# <style>
# #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
#
# div #notebook { /* centre the content */
#     background: #FFFFF0;  /* IVORY */
#     color: #333;
#     width: 115ex;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
#
# div.text_cell_render {  /*Markdown cells */
#     font-family: Computer Modern Roman;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0; /*What is this */
#     padding: 0.05; /*Spacing between cells*/
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0.05;
# }
#
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h3 {
#     margin: 0;
#     padding: 0;
# }
#
# /* Width of all cells */
# div.cell { /* set cell width to about 80 chars */
#     width: 55em;
#
# }
#
# /* Set font of coding cells (DONT KNOW WHY BUT NEED THIS) */
# .CodeMirror {
#     /* Preferred font is bold sawasdee, but here are backups */
#     font-family: "Sawasdee", "Lucida Sans Typewriter","Lucida Typewriter",
#          "Lucida Typewriter", "Courier New", Courier, monospace;;
#     font-size: normal;
#     font-weight: 700;
# }
#
# div.cell.code_cell { /* Total code cell, in and out */
#     background: #FFFFF0;
#     border: none;
#     padding-top: 1ex;
# }
#
# div.input_area { /* box around box with code ??? */
#     border: none;
#     background: #f5f5f5;
#     border: 1px solid #fff;
#     border-radius: 10px;
#     padding-top: 0.5ex;
#     padding-bottom: 0.5ex;
#     padding-left: 0.5em;
# }
#
# div.input { /* box with code */
# }
#
#
# div.prompt { /* remove In/Out prompt */
#     display: none;
# }
#
# div.output_subarea { /* remove margin in front of output */
#     border: none;
# }
#
# div.cell.border-box-sizing.code_cell.running {
#     /* draw red dotted border around running cells */
#     border: 3px dotted #f33;
# }
#
# /* header colours and fonts */
# h1 { color: #444; }
# h2 { color: #444; font-style: oblique}
# h3 { color: #0000A0; font-weight: normal}
# h4 { color: #444; font-weight: oblique; font-size: large}
#
#
# </style>

# %% [markdown]
# #### Initialization (from list of canvases (*canvii*) )

# %% [markdown]
# Let's use "Canvas.random_circles()* to generate 10 canvases with a random number of circles between 1 and 50 and random names.  The random name generator was taken from [this thread](http://stackoverflow.com/questions/2257441/python-random-string-generation-with-upper-case-letters-and-digits).
#
# MultiCanvas must be initialized with a **names** and **canvii** instance; both must be equally-sized lists.  We will show alternative constructors subsequently.

# %%
import string
import random 
from pyparty import MultiCanvas

def rand_name(size=6, chars=string.ascii_lowercase + string.digits):
     return ''.join(random.choice(chars) for _ in range(size))

names, canvii = [], []
for i in range(10):
    names.append( rand_name() )
    canvii.append( Canvas.random_circles(n=random.randint(1,100)) )
    
mc = MultiCanvas(names=names, canvii=canvii)
mc
# Out:
# MultiCanvas at 0xc07de0c:
#    bbp2f9:   Canvas (0xb0156bc) : 512 X 512 : 1 particles
#    guovnn:   Canvas (0xba699bc) : 512 X 512 : 51 particles
#    s279f0:   Canvas (0xbae508c) : 512 X 512 : 28 particles
#    m8ttj2:   Canvas (0xbc05dac) : 512 X 512 : 81 particles
#    xqpdv9:   Canvas (0xbc4844c) : 512 X 512 : 4 particles
#    nyjrnz:   Canvas (0xbd8832c) : 512 X 512 : 82 particles
#    ndd9aj:   Canvas (0xbdeac8c) : 512 X 512 : 30 particles
#    cy6w3y:   Canvas (0xbef7c2c) : 512 X 512 : 73 particles
#    m88hiw:   Canvas (0xbfbbc5c) : 512 X 512 : 47 particles
#    61dufu:   Canvas (0xc07dc8c) : 512 X 512 : 47 particles

# %% [markdown]
# #### Sorting

# %% [markdown]
# Let's sort this (by name).  When sorting multicanvas, <font color='red'>**do not use pythons sorted() function; used mc.sort()**</font>

# %%
mc.sort(inplace=True)
mc
# Out:
# MultiCanvas at 0xc07de0c:
#    61dufu:   Canvas (0xc07dc8c) : 512 X 512 : 47 particles
#    bbp2f9:   Canvas (0xb0156bc) : 512 X 512 : 1 particles
#    cy6w3y:   Canvas (0xbef7c2c) : 512 X 512 : 73 particles
#    guovnn:   Canvas (0xba699bc) : 512 X 512 : 51 particles
#    m88hiw:   Canvas (0xbfbbc5c) : 512 X 512 : 47 particles
#    m8ttj2:   Canvas (0xbc05dac) : 512 X 512 : 81 particles
#    ndd9aj:   Canvas (0xbdeac8c) : 512 X 512 : 30 particles
#    nyjrnz:   Canvas (0xbd8832c) : 512 X 512 : 82 particles
#    s279f0:   Canvas (0xbae508c) : 512 X 512 : 28 particles
#    xqpdv9:   Canvas (0xbc4844c) : 512 X 512 : 4 particles

# %% [markdown]
# #### Indexing

# %% [markdown]
# Indexing is as you'd expect.  Valid indicies include:
#    - Integer
#    - Integer slice
#        - eg [5:3], [3::] etc...
#    - Single name (string)
#
# A slice that returns multiple objects will return a MulitCanvas.  A slice that returns a single element will return a Canvas.  This is the same behavior as Python's list slicing.

# %%
print mc[4:7]

NAME = mc.names[0]
mc[NAME].show(title='Showing Canvas ``%s"' % NAME);
# Out:
# MultiCanvas at 0xc51186c:
#    m88hiw:   Canvas (0xbfbbc5c) : 512 X 512 : 47 particles
#    m8ttj2:   Canvas (0xbc05dac) : 512 X 512 : 81 particles
#    ndd9aj:   Canvas (0xbdeac8c) : 512 X 512 : 30 particles

# %% [markdown]
# Setting a deleting by item are also supported, **but only by single key**; the same as a python dictionary:

# %%
mc['test'] = Canvas.random_circles(n=20)
print mc['test']
del mc['test']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-886aab76363a> in <module>()
# ----> 1 mc['test'] = Canvas.random_circles(n=20)
#       2 print mc['test']
#       3 del mc['test']
#
# /home/adam/Desktop/pyparty/pyparty/multi.py in __setitem__(self, key, canvas)
#     319     def __setitem__(self, key, canvas):
#     320         """ """
# --> 321         idx = self.names.index(key)
#     322         self.pop(idx)
#     323         self.names.insert(idx, key)
#
# ValueError: 'test' is not in list

# %% [markdown]
# #### Plotting (histogram and pie chart)

# %% [markdown]
# #### Transmuting

# %% [markdown]
# Sometimes we'd like to output the MultiCanvas as a standard Python type, such as a dictionary with names as keys and canvii as values.  Or maybe we don't want the whole canvas, we just need the particle area array or the binary image, or any other valid canvas attribute.  **mc.transmute()** provides a general and simple method for this.  One specifies merely two options:
#
# -  as_type: tuple, dict, OrderedDict, None
#     - Output (name, value) as desired type.  If None, a generator expression is returned.
# - attr: str or None
#     - Any valid canvas attribute.  If None, the entire canvas is returned as the *value* in (name, value) pairs.
#
# So, let's output a dictionary of names, areas, and a list of tuple pairs of names, grayimage.

# %%
area_dict = mc.transmute(attr='area', as_type=dict)
tuple_imgs = mc.transmute(attr='grayimage', as_type=tuple)

print type(area_dict), type(tuple_imgs)

name, grayimg = tuple_imgs[0]
showim(grayimg, title='Showing ``%s" from tuple transmute' % name);
# Out:
# <type 'dict'> <type 'tuple'>

# %% [markdown]
# #### Alternate Constructors

# %% [markdown]
# ### Related

# %% [markdown]
# - pyparty: https://github.com/hugadams/pyparty
# - notebook: [Labeling Nanogold](http://nbviewer.ipython.org/github/hugadams/pyparty/blob/master/examples/Notebooks/groups_of_labels.ipynb?create=1)

# %% [markdown]
# ### Redistribution

# %% [markdown]
# This notebook is free for redistribution.  If referencing, please cite as:
#
# - Hughes, A. (2012). [A Computational Framework for Plasmonic Nanobiosensing](https://www.researchgate.net/publication/236672995_A_Computational_Framework_for_Plasmonic_Nanobiosensing).  Python in Science Conference [SCIPY].
