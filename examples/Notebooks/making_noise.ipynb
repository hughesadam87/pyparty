# %% [raw]
# Adam Hughes
# 2/12/2014
# George Washington Universrty, Physics Dept.

# %% [markdown]
# # Creating SEM test data: Part 1

# %%
from pyparty import Canvas, Grid, any2rgb, splot, showim
from pyparty.utils import grayhist
from pyparty.bundled import load_style
load_style('louic')
# Out:
# <style>
# #notebook_panel { /* main background */
#     background: #333;
#     color: #f6f6f6;
# }
#
# div #notebook { /* centre the content */
#     background: #fff;
#     color: #333;
#     width: 115ex;
#     margin: auto;
#     padding-left: 1em;
#     padding-right: 1em;
#     padding-top: 2ex;
# }
#
# /* remove big margins around title */
# div.text_cell_render.border-box-sizing.rendered_html {
#     margin: 0;
#     padding: 0;
#     margin-left: 1ex;
# }
# div.cell.text_cell.border-box-sizing {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h1 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h2 {
#     margin: 0;
#     padding: 0;
# }
# .rendered_html h3 {
#     margin: 0;
#     padding: 0;
# }
#
# div.cell { /* set cell width to about 80 chars */
#     width: 55em;
# }
#
# div.cell.code_cell { /* area that contains code + output */
#     background: #fff;
#     border: none;
#     border-radius: 10px;
#     padding-top: 1ex;
# }
#
# div.input_area { /* box around box with code */
#     border: none;
#     background: #f5f5f5;
#     border: 1px solid #ccc;
#     border-radius: 10px;
#     padding-top: 0.5ex;
#     padding-bottom: 0.5ex;
#     padding-left: 0.5em;
# }
#
# div.input { /* box with code */
# }
#
# div.CodeMirror { /* code font */
#     font-family: "Inconsolata-dz", monospace;
#     font-size: 10pt;
# }
#
# div.prompt { /* remove In/Out prompt */
#     display: none;
# }
#
# div.output_subarea { /* remove margin in front of output */
#     border: none;
# }
#
# div.cell.border-box-sizing.code_cell.running {
#     /* draw border around running cells */
#     border: 3px dotted #f33;
# }
#
# /* header colours and fonts */
# h1 { color: #444; }
# h2 { color: #444; }
# h3 { color: #444; font-style: italic; font-weight: normal}
#
#
# </style>

# %% [markdown]
# Our task is to generate some test data for SEM images that can be used to test various segmentation algorithms.  We'd like to test how well the algorithms perform in segmenting particles at in the presence of uneven contrast, noise and various degrees of particle overlap.  First, let's define some constants to help reuse this scripts

# %%
RESOLUTION = (1024, 1024)   #Image resolution
BGGRAY = 128                     #Light gray background
PCOLOR = 255                      #White particles
NOISE_DENSITY = 0.15      #percent
DIAM_SINGLE = 20 #pixels

# %% [markdown]
# #### Step 1: Create a light-gray background; add particles

# %%
c = Canvas(rez=RESOLUTION, background=BGGRAY)
c.grid.ydiv=30

for (cx, cy) in c.gpairs('centers'):
    c.add('circle', radius=DIAM_SINGLE/2, center=(cx,cy), color=PCOLOR)
    
c.show()

def summary(c):
    """ Return summary string from canvas """   
    diam_mu = c.area.mean()
    return '%i particles; %.2f percent coverage; %.1f average area(px^2)' % \
             (len(c), 100*c.pixarea, diam_mu)
    
summary(c)
# Out:
# '870 particles; 25.31 percent coverage; 305.0 average area(px^2)'

# %% [markdown]
# #### Step 3: Add a constant and uneven contrast gradient using "Grid".

# %% [markdown]
# **Note**: We use any2rgb() to RGB-convert the background so that plotting doesn't try to normalize the colors.

# %%
def warped(xx, yy, power=1.0):
    """ 2d function to generate uneven contrasts """
    return abs(np.cos(xx**power) + np.sin(yy**power))

g1 = Grid(style='h', rez=RESOLUTION)
gradientbg = g1.blend_bg(c.image, weight=0.35)
gradientbg = any2rgb(gradientbg)

g2 = Grid(rez=RESOLUTION)
g2.set_zfcn(warped)
warpedbg = g2.blend_bg(c.image, weight=0.25)
warpedbg = any2rgb(warpedbg)

axes = splot(1,3, figsize=(15,15))

IMAGES = [c.image, gradientbg, warpedbg]

for (idx, img) in enumerate(IMAGES):
    showim(img, 'gray', axes[idx]);

# %% [markdown]
# #### Step 4: Add some noise

# %%
from pyparty.noise import salt

axes = splot(1,3, figsize=(15,15))

for idx, img in enumerate(IMAGES):
    noisyimg = salt(img, coverage=NOISE_DENSITY)
    showim(noisyimg, 'gray', axes[idx])

# %% [markdown]
# Just a side note, the types of valid noise are:
#
# - salt
# - pepper
# - saltpepper
# - color (default = yellow)
# - multicolor
# - normal
#
# Where one color takes valid pyparty color (eg 'red', #0000FF, 230, (.5, .5, .5) ).  Noise is always randomly distributed across the image.  Multicolor noise is random 3-channel (r,g,b), where each channel is randomly chosen on 0-1 interval.

# %%
from pyparty.noise import salt, pepper, saltpepper, color, multicolor

# Function that adds no noise: for plot 1
def nonoise(img, coverage): return img

noisefcns = (nonoise, salt, pepper, saltpepper, color, multicolor)
axes = splot(2,3, figsize=(15,10))

for idx, noisefcn in enumerate(noisefcns):
    ax, title = axes[idx], noisefcn.__name__
    showim(noisefcn(warpedbg, NOISE_DENSITY), ax, title=title);

# %% [markdown]
# ## Part 2: Multi-particle species

# %%
STD_DEV = 3  # pixels
PCOLOR = 200 #Single color

# %%
from random import choice
COUNT = len(c.gpairs('centers'))

rand_diam = np.random.normal(loc=DIAM_SINGLE, 
                                scale=STD_DEV, size=2000)

# %%
import random

def rint(x):
    return int(round(x, 0))

def rran(samples=1):
    """ Pick a random radius from distribution. """
    return [rint(choice(rand_diam)/2.0) for i in range(samples)]

def rphi():
    return rint(random.random() * 360.0)

def roverlap():
    return 0  +  (random.random() * .2 ) 

def populate_canvas(c):
    for (cx, cy) in c.gpairs('centers'):
        idx, pcolor = choice([(1, PCOLOR), (2, PCOLOR+15), (3, PCOLOR+35),(4, PCOLOR+55)])
        shared = {'color':pcolor, 'center':(cx,cy), 
              'phi':rphi(), 'overlap':roverlap()}

        if idx == 1:
            c.add('circle', radius=rran()[0], **shared)
        elif idx == 2:
            c.add('dimer', *rran(2), **shared)
        elif idx == 3:
            c.add('trimer', *rran(3),**shared)                
        elif idx == 4:
            c.add('tetramer', *rran(4), **shared)

# %%
c.clear_particles()
c.grid.xdiv = c.grid.ydiv = 20
populate_canvas(c)
c.show()

# %%
ax1, ax2 = splot(1,2, figsize=(10,6))
c.show(ax1)
ax2.hist(c.equivalent_diameter, bins=37, alpha=.5, color='orange')
ax2.set_xlabel('Equivalent Diameter');

# %%
c_blend = g2.blend_bg(c.grayimage, weight=0.35)
c_blend_noise = salt(c_blend, NOISE_DENSITY)

imshow(any2rgb(c_blend), 'gray');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-678983c5e61a> in <module>()
#       1 c_blend = g2.blend_bg(c.grayimage, weight=0.35)
# ----> 2 c_blend_noise = salt(c_blend, NOISE_DENSITY)
#       3
#       4 imshow(any2rgb(c_blend), 'gray');
#
# /home/adam/Desktop/pyparty/pyparty/noise.pyc in salt(img, coverage)
#     101 def salt(img, coverage=DEFAULT_COVERAGE):
#     102     """White noise"""
# --> 103     return color(img, coverage, (1,1,1),)
#     104
#     105
#
# /home/adam/Desktop/pyparty/pyparty/utils.pyc in wrapper(*args, **kwargs)
#      64         args=list(args)
#      65         args[0] = np.copy(args[0])
# ---> 66         return fcn(*args, **kwargs)
#      67     return wrapper
#      68
#
# /home/adam/Desktop/pyparty/pyparty/noise.pyc in color(img, coverage, intensity)
#      47
#      48     _parse_coverage(coverage)
# ---> 49     intensity = _parse_intensity(img, intensity)
#      50     noisey = RANDSAMP(size=img.shape[0:2])
#      51     img[noisey > 1- coverage] = intensity
#
# /home/adam/Desktop/pyparty/pyparty/noise.pyc in _parse_intensity(img, intensity)
#      21     intensity = to_normrgb(intensity)
#      22     if img.ndim == 2:
# ---> 23         intensity = rgb2uint(intensity)
#      24     return intensity
#      25
#
# /home/adam/Desktop/pyparty/pyparty/utils.pyc in rgb2uint(image, warnmsg)
#     177
#     178     # DOES NOT CHECK IMAGE DIMENSIONS; LEAVES THAT TO CALLING OBJECT
# --> 179     grayimg = img_as_ubyte( rgb2gray(image) )
#     180     if warnmsg:
#     181         if isinstance(warnmsg, str):
#
# /home/adam/Enthought/Canopy_32bit/User/lib/python2.7/site-packages/skimage/color/colorconv.pyc in rgb2gray(rgb)
#     656     >>> lena_gray = rgb2gray(lena)
#     657     """
# --> 658     if rgb.ndim == 2:
#     659         return rgb
#     660
#
# AttributeError: 'tuple' object has no attribute 'ndim'

# %%
circ = np.pi *( ( 4 * c.area) / (c.perimeter)**2 )
plt.scatter(c.equivalent_diameter, circ)
