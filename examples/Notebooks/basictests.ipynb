# %%
from pyparty.tools.canvas import Canvas

#c=Canvas(background='/home/glue/Desktop/half_pump.jpg')
c=Canvas()
c.add('circle', radius=100, center=(500,500), color=(0,1,0))
c.add('circle', radius=200, center=(100,100), color=(0,.1,.5))
c.show();

# %%
c.load_background('/home/glue/Desktop/half_pump.jpg')
c.show();

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

ax1.set_title('ax1')
c.show(ax1)

#Add a particle
c.add('circle', radius=20, center=(100,100), color=(0,1,1))

ax2.set_title('ax2 (extra cyan particle)')
c.show(ax2);

# %%
c.clear_particles()
c.show();

# %%
c.reset_background()
c.show();
